# %%
# !pip install google-api-python-client pandas

# %%
from googleapiclient.discovery import build

api_key = ""
youtube = build('youtube', 'v3', developerKey=api_key)

def get_comments(video_id, max_pages=20):
    comments = []

    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        textFormat="plainText"
    )

    for _ in range(max_pages):
        response = request.execute()

        for item in response['items']:
            snippet = item['snippet']['topLevelComment']['snippet']

            comments.append({
                "text": snippet['textDisplay'],
                "likes": snippet['likeCount'],
                "published": snippet['publishedAt']
            })

        # pagination (WAJIB)
        if 'nextPageToken' not in response:
            break

        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=100,
            pageToken=response['nextPageToken'],
            textFormat="plainText"
        )

    return comments

# %%
from googleapiclient.discovery import build

api_key = "AIzaSyCRvy3wu-7INy1d0VE2yj8x8sqA6VT3NME"
youtube = build('youtube', 'v3', developerKey=api_key)

def search_videos(query):
    request = youtube.search().list(
        q=query,
        part="snippet",
        type="video",
        maxResults=50
    )
    response = request.execute()

    video_ids = []
    for item in response['items']:
        video_ids.append(item['id']['videoId'])

    return video_ids

video_ids = search_videos("orang desa tidak pakai dolar")
print(video_ids)
# Out:
# ['O3-IACpR3qQ', 'HZ4xmVtNDwc', 'LSqY2K0MFxM', 'e1VUNrOIQS4', 'NllWRqW6MPA', 'oggybiqJwbw', 'moguSUGfPgM', 'v4ZZhiWXt-8', '1aDgk7A17Vs', 'REwNliSjFA8', '6KP2W1djB6c', 'QMr_459H6L0', 'TLljaciE1OU', 'QcfOecnhrBw', 'XlxuEFkTHps', 'wRrMVD5DfUs', 'nPiYoVfI9FY', 'pMW4i5gIxSA', '-yN8tmYekGM', '73vUi7gRBIw', 'qwfIVaoI3pk', 'QnlhI_B6sE0', 'Ba6LK9cWtvE', 'q77zHgaLAlU', 'ZNcNJBytFAw', '9oPk6GVSzfI', '-CR3_A3YvWo', 'cpuswVhxaDc', 'dCrDrLnGtWo', 'tNsyosmqkm4', 'zX94kjuW1Rg', 'u3LJXPrDZE4', 'RIziFa1R6ko', '4gl4eYtXcCg', 'UJatfW9mKyU', '24CHdc2euuU', 'MSOngV_Mw1I', 'BaIKk3kC2Pc', 'cFjYpipr3hI', 'RBkn-kLOd3M', 'iEuikS4ldWw', '71ca5Ft6ee4', 'pn1Tj6vMn-o', 'drM-c74UIp8', 'Zrc3nwS9cIo', '7tMAJbS0sWo', 'X4bUk-TChmI', '2OrFhdhMytE', 'ttFAIenYMjI', 'ov9JVwcVkjo']

# %%
for vid in video_ids:
    try:
        data = get_comments(vid)
        all_comments.extend(data)
        print(f"SUCCESS: {vid}")
    except Exception as e:
        print(f"SKIPPED: {vid} - {e}")
# Out:
# SKIPPED: O3-IACpR3qQ - name 'all_comments' is not defined
# SKIPPED: HZ4xmVtNDwc - name 'all_comments' is not defined
# SKIPPED: LSqY2K0MFxM - name 'all_comments' is not defined
# SKIPPED: e1VUNrOIQS4 - name 'all_comments' is not defined
# SKIPPED: NllWRqW6MPA - name 'all_comments' is not defined
# SKIPPED: oggybiqJwbw - name 'all_comments' is not defined
# SKIPPED: moguSUGfPgM - name 'all_comments' is not defined
# SKIPPED: v4ZZhiWXt-8 - name 'all_comments' is not defined
# SKIPPED: 6KP2W1djB6c - name 'all_comments' is not defined
# SKIPPED: REwNliSjFA8 - name 'all_comments' is not defined
# SKIPPED: QcfOecnhrBw - name 'all_comments' is not defined
# SKIPPED: 1aDgk7A17Vs - name 'all_comments' is not defined
# SKIPPED: TLljaciE1OU - name 'all_comments' is not defined
# SKIPPED: QMr_459H6L0 - name 'all_comments' is not defined
# SKIPPED: XlxuEFkTHps - name 'all_comments' is not defined
# SKIPPED: wRrMVD5DfUs - name 'all_comments' is not defined
# ...

# %%
def get_video_stats(video_id):
    request = youtube.videos().list(
        part="statistics",
        id=video_id
    )
    response = request.execute()

    stats = response['items'][0]['statistics']
    return stats.get("commentCount", 0)

# %%
video_ids = ['UkCNdhAJTGg']






all_comments = []

for vid in video_ids:
    try:
        count = get_video_stats(vid)

        if int(count) == 0:
            print(f"NO COMMENTS: {vid}")
            continue

        data = get_comments(vid)
        all_comments.extend(data)

        print(f"OK: {vid} ({len(data)} comments)")

    except Exception as e:
        print(f"ERROR: {vid} - {e}")
# Out:
# OK: O3-IACpR3qQ (138 comments)
# OK: HZ4xmVtNDwc (937 comments)
# OK: LSqY2K0MFxM (798 comments)
# OK: e1VUNrOIQS4 (113 comments)
# OK: NllWRqW6MPA (337 comments)
# OK: oggybiqJwbw (499 comments)
# OK: moguSUGfPgM (1215 comments)
# OK: v4ZZhiWXt-8 (1 comments)
# OK: 1aDgk7A17Vs (180 comments)
# NO COMMENTS: REwNliSjFA8
# OK: 6KP2W1djB6c (381 comments)
# OK: QMr_459H6L0 (4 comments)
# OK: TLljaciE1OU (24 comments)
# OK: QcfOecnhrBw (3 comments)
# OK: XlxuEFkTHps (105 comments)
# OK: wRrMVD5DfUs (112 comments)
# OK: nPiYoVfI9FY (1337 comments)
# OK: pMW4i5gIxSA (10 comments)
# OK: -yN8tmYekGM (420 comments)
# OK: 73vUi7gRBIw (1 comments)
# OK: qwfIVaoI3pk (1 comments)
# OK: QnlhI_B6sE0 (279 comments)
# OK: Ba6LK9cWtvE (576 comments)
# OK: q77zHgaLAlU (151 comments)
# OK: ZNcNJBytFAw (60 comments)
# OK: 9oPk6GVSzfI (60 comments)
# OK: -CR3_A3YvWo (1 comments)
# NO COMMENTS: cpuswVhxaDc
# OK: dCrDrLnGtWo (117 comments)
# OK: tNsyosmqkm4 (1 comments)
# OK: zX94kjuW1Rg (41 comments)
# ...
